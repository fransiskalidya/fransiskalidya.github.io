# %% [markdown]
# <a href="https://colab.research.google.com/github/fransiskalidya/fransiskalidya.github.io/blob/main/Latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Fransiska Lidya Kartika"
nim = 1941720106

print("nama = ", nama,"\n", "nim = ", nim)
# Out:
# nama =  Fransiska Lidya Kartika
#  nim =  1941720106

# %%
pip install pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

dataset = '/content/sample_data/DataDummyKAO.csv'
with open(dataset) as inisial_file:
  baca_file = csv.reader(inisial_file, delimiter = ',')
  for baris in baca_file:
    print(baris)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# ['2013', '01/21/2013', '01/17/2013', '22110', '221105194443', '100275', 'KAO INDONESIA PT', '102614694', 'BIORE BF PURE MILD PCH 250 ML', '120', '120', 'Complate']
# ['2013', '01/21/2013', '01/17/2013', '22110', '221105194452', '100275', 'KAO INDONESIA PT', '102606247', 'BIORE BF SILKY SMOOTH POUCH 450 ML', '240', '240', 'Complate']
# ['2013', '01/21/2013', '01/17/2013', '22110', '221105194430', '100275', 'KAO INDONESIA PT', '102605999', 'BIORE BF FRESH BLOSSOM POUCH 450ml', '60', '60', 'Complate']
# ['2013', '01/21/2013', '01/17/2013', '22110', '221105194452', '100275', 'KAO INDONESIA PT', '102603553', 'BIORE BF CHARMING FREESIA PCH 450 ML', '180', '180', 'Complate']
# ['2013', '01/21/2013', '01/17/2013', '22110', '221105194430', '100275', 'KAO INDONESIA PT', '102425497', "LAURIER RELAX NIGHT WING 27CM 20'S", '100', '0', 'Complate']
# ...
